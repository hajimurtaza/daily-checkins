# %% [markdown]
# # EXPLORATORY DATA ANALYSIS USING PANDAS AND SEABORN LIBRARIES    IN  PYTHON

# %% [markdown]
# ### CHECKOUT datacamp, udemy, coursera for basic data analysis in python

# %%
import pandas as pd
# %matplotlib inline

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

rcParams['figure.figsize'] = 10,8
plt.rcParams["axes.labelsize"] = 20
sns.set_style('whitegrid')

# %% [markdown]
# # This is the dataset for soccer players describing their personal and physical  attributes

# %%
df_full = pd.read_csv('Fifa2017.csv')

# %%
df_full.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# ...

# %%
df_full.describe()
# Out:
#        National_Kit      Club_Kit  Contract_Expiry        Rating  \
# count   1075.000000  17587.000000     17587.000000  17588.000000
# mean      12.219535     21.294536      2018.899414     66.166193
# std        6.933187     19.163741         1.698787      7.083012
# min        1.000000      1.000000      2017.000000     45.000000
# 25%        6.000000      9.000000      2017.000000     62.000000
# 50%       12.000000     18.000000      2019.000000     66.000000
# 75%       18.000000     27.000000      2020.000000     71.000000
# max       36.000000     99.000000      2023.000000     94.000000
#
#                 Age     Weak_foot   Skill_Moves  Ball_Control     Dribbling  \
# count  17588.000000  17588.000000  17588.000000  17588.000000  17588.000000
# mean      25.460314      2.934103      2.303161     57.972766     54.802877
# std        4.680217      0.655927      0.746156     16.834779     18.913857
# ...

# %%
df_full.shape
# Out:
# (17588, 53)

# %%
df_full.columns
# Out:
# Index(['Name', 'Nationality', 'National_Position', 'National_Kit', 'Club',
#        'Club_Position', 'Club_Kit', 'Club_Joining', 'Contract_Expiry',
#        'Rating', 'Height', 'Weight', 'Preffered_Foot', 'Birth_Date', 'Age',
#        'Preffered_Position', 'Work_Rate', 'Weak_foot', 'Skill_Moves',
#        'Ball_Control', 'Dribbling', 'Marking', 'Sliding_Tackle',
#        'Standing_Tackle', 'Aggression', 'Reactions', 'Attacking_Position',
#        'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short_Pass',
#        'Long_Pass', 'Acceleration', 'Speed', 'Stamina', 'Strength', 'Balance',
#        'Agility', 'Jumping', 'Heading', 'Shot_Power', 'Finishing',
#        'Long_Shots', 'Curve', 'Freekick_Accuracy', 'Penalties', 'Volleys',
#        'GK_Positioning', 'GK_Diving', 'GK_Kicking', 'GK_Handling',
#        'GK_Reflexes'],
#       dtype='object')

# %% [markdown]
# # Ran the following queries to check for null values

# %%
# df.isnull().any()
# df.shape = 17588
# df.dropna(axis = 0, how='any', inplace=True)
# df.shape = 17587

# %% [markdown]
# # Dropping columns with irrelevant values

# %%
df_full.drop(['National_Kit','National_Position', 'Birth_Date','Name','Club_Kit','Club_Joining','Contract_Expiry','Preffered_Position'], axis= 1, inplace= True)
# df_full.drop(, axis= 1, inplace= True)

# %% [markdown]
# # Finding range of ages of players in dataset

# %%
df_full.Age.unique()
# Out:
# array([32, 29, 25, 30, 31, 26, 28, 27, 35, 24, 33, 34, 39, 23, 22, 36, 21,
#        20, 37, 19, 38, 40, 18, 44, 42, 17, 43, 41, 47], dtype=int64)

# %%
df_full.head()
# Out:
#   Nationality          Club Club_Position  Rating  Height Weight  \
# 0    Portugal   Real Madrid            LW      94  185 cm  80 kg
# 1   Argentina  FC Barcelona            RW      93  170 cm  72 kg
# 2      Brazil  FC Barcelona            LW      92  174 cm  68 kg
# 3     Uruguay  FC Barcelona            ST      92  182 cm  85 kg
# 4     Germany     FC Bayern            GK      92  193 cm  92 kg
#
#   Preffered_Foot  Age        Work_Rate  Weak_foot     ...       Long_Shots  \
# 0          Right   32       High / Low          4     ...               90
# 1           Left   29  Medium / Medium          4     ...               88
# 2          Right   25    High / Medium          5     ...               77
# 3          Right   30    High / Medium          4     ...               86
# 4          Right   31  Medium / Medium          4     ...               16
#
#    Curve  Freekick_Accuracy  Penalties  Volleys  GK_Positioning  GK_Diving  \
# ...

# %% [markdown]
# # Taking a random sample of the dataset

# %%
df = df_full.sample(n=3000)

# %% [markdown]
# # Check For  Null Values

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Making a list of  columns in the dataset for plotting values

# %%
rating = df['Rating']

# %%
longshot = df['Long_Shots']

# %%
reactions = df['Reactions']
age= df['Age']
# reactions.plot()

# %% [markdown]
# # Plotting lists to understand trends in the dataset

# %%
sns.distplot(df.Rating)

# %%
sns.distplot(df.Age)

# %%
sns.distplot(df.Reactions)

# %%
# df.columns

# %% [markdown]
# # Boxplot to understand the age and number of players in each position

# %%
sns.boxplot(df_full.Age, df_full.Club_Position)

# %%
byclub_position = df.groupby('Club_Position')

# %%
byclub_position.count()
# Out:
#                Nationality  Club  Rating  Height  Weight  Preffered_Foot  \
# Club_Position
# CAM                     63    63      63      63      63              63
# CB                      13    13      13      13      13              13
# CDM                     12    12      12      12      12              12
# CF                       1     1       1       1       1               1
# CM                      11    11      11      11      11              11
# GK                     110   110     110     110     110             110
# LAM                     12    12      12      12      12              12
# LB                      80    80      80      80      80              80
# LCB                    100   100     100     100     100             100
# LCM                     73    73      73      73      73              73
# LDM                     41    41      41      41      41              41
# LF                       3     3       3       3       3               3
# ...

# %% [markdown]
# # Plots for looking  at possible assumed trends in the dataset

# %%
df.plot(kind='scatter', x='Age', y = 'Rating')

# %%
sns.regplot( x='Age', y = 'Rating', data = df, scatter = True)

# %%
df.head()
# Out:
#       Nationality              Club Club_Position  Rating  Height Weight  \
# 1756       Brazil    Paços Ferreira            ST      75  180 cm  74 kg
# 10700       Italy              Pisa           Sub      64  180 cm  73 kg
# 15745       Italy           Crotone           Res      57  180 cm  73 kg
# 16647    Colombia      Boyacá Chicó            RB      54  178 cm  70 kg
# 12113   Argentina  Parque Patricios            ST      63  186 cm  86 kg
#
#       Preffered_Foot  Age        Work_Rate  Weak_foot     ...       \
# 1756            Left   24       High / Low          3     ...
# 10700          Right   20  Medium / Medium          3     ...
# 15745           Left   18  Medium / Medium          2     ...
# 16647          Right   18  Medium / Medium          3     ...
# 12113          Right   24       High / Low          3     ...
#
#        Long_Shots  Curve  Freekick_Accuracy  Penalties  Volleys  \
# 1756           63     81                 79         69       72
# ...

# %%
df.columns
# Out:
# Index(['Nationality', 'Club', 'Club_Position', 'Rating', 'Height', 'Weight',
#        'Preffered_Foot', 'Age', 'Work_Rate', 'Weak_foot', 'Skill_Moves',
#        'Ball_Control', 'Dribbling', 'Marking', 'Sliding_Tackle',
#        'Standing_Tackle', 'Aggression', 'Reactions', 'Attacking_Position',
#        'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short_Pass',
#        'Long_Pass', 'Acceleration', 'Speed', 'Stamina', 'Strength', 'Balance',
#        'Agility', 'Jumping', 'Heading', 'Shot_Power', 'Finishing',
#        'Long_Shots', 'Curve', 'Freekick_Accuracy', 'Penalties', 'Volleys',
#        'GK_Positioning', 'GK_Diving', 'GK_Kicking', 'GK_Handling',
#        'GK_Reflexes'],
#       dtype='object')

# %% [markdown]
# # Creating a dataframe using values which are presumed to be related

# %%
df_subset= df[['Age', 'Rating', 'Work_Rate', 'Dribbling','Reactions','Acceleration', 'Vision','Long_Pass']].copy()

# %%
sns.pairplot(df_subset)

# %% [markdown]
# # We can see several columns showing linear relationship

# %%
sns.regplot( x='Reactions', y = 'Rating', data = df, scatter = True)

# %%
sns.regplot( x='Vision', y = 'Long_Pass', data = df, scatter = True)

# %%
sns.regplot( x='Reactions', y = 'Age', data = df, scatter = True)

# %%
df.head()
# Out:
#       Nationality              Club Club_Position  Rating  Height Weight  \
# 1756       Brazil    Paços Ferreira            ST      75  180 cm  74 kg
# 10700       Italy              Pisa           Sub      64  180 cm  73 kg
# 15745       Italy           Crotone           Res      57  180 cm  73 kg
# 16647    Colombia      Boyacá Chicó            RB      54  178 cm  70 kg
# 12113   Argentina  Parque Patricios            ST      63  186 cm  86 kg
#
#       Preffered_Foot  Age        Work_Rate  Weak_foot     ...       \
# 1756            Left   24       High / Low          3     ...
# 10700          Right   20  Medium / Medium          3     ...
# 15745           Left   18  Medium / Medium          2     ...
# 16647          Right   18  Medium / Medium          3     ...
# 12113          Right   24       High / Low          3     ...
#
#        Long_Shots  Curve  Freekick_Accuracy  Penalties  Volleys  \
# 1756           63     81                 79         69       72
# ...

# %% [markdown]
# # Eyeballing the statistical values to get a feel for the distribution in the data

# %%
df.mean()
# Out:
# Rating                66.319000
# Age                   25.481667
# Weak_foot              2.926000
# Skill_Moves            2.310333
# Ball_Control          58.226000
# Dribbling             54.988667
# Marking               44.770000
# Sliding_Tackle        45.986000
# Standing_Tackle       47.948000
# Aggression            56.403667
# Reactions             61.977667
# Attacking_Position    49.687000
# Interceptions         47.233000
# Vision                52.858667
# Composure             55.908000
# Crossing              49.895667
# Short_Pass            58.308667
# Long_Pass             52.535000
# Acceleration          65.292000
# Speed                 65.432667
# Stamina               63.839333
# Strength              65.136000
# Balance               64.135333
# Agility               63.513333
# Jumping               64.716333
# Heading               52.704667
# Shot_Power            55.817667
# Finishing             45.470333
# Long_Shots            47.675000
# ...

# %%
df.std()
# Out:
# Rating                 7.128360
# Age                    4.695070
# Weak_foot              0.659800
# Skill_Moves            0.752916
# Ball_Control          16.839362
# Dribbling             18.886824
# Marking               21.539911
# Sliding_Tackle        21.381804
# Standing_Tackle       21.689954
# Aggression            17.407060
# Reactions              9.137961
# Attacking_Position    19.476091
# Interceptions         20.349957
# Vision                14.732471
# Composure             13.787950
# Crossing              18.413142
# Short_Pass            15.012190
# Long_Pass             15.567216
# Acceleration          14.511361
# Speed                 14.123336
# Stamina               15.441492
# Strength              12.686390
# Balance               13.862843
# Agility               14.631924
# Jumping               11.695959
# Heading               17.511339
# Shot_Power            17.640601
# Finishing             19.361166
# Long_Shots            19.258513
# ...

# %%
df_subset.corr()
# Out:
#                    Age    Rating  Dribbling  Reactions  Acceleration  \
# Age           1.000000  0.468991   0.008003   0.463702     -0.176359
# Rating        0.468991  1.000000   0.368853   0.829975      0.193830
# Dribbling     0.008003  0.368853   1.000000   0.344653      0.734219
# Reactions     0.463702  0.829975   0.344653   1.000000      0.173166
# Acceleration -0.176359  0.193830   0.734219   0.173166      1.000000
# Vision        0.201673  0.486618   0.728049   0.474711      0.444650
# Long_Pass     0.185584  0.483610   0.715222   0.439067      0.440249
#
#                 Vision  Long_Pass
# Age           0.201673   0.185584
# Rating        0.486618   0.483610
# Dribbling     0.728049   0.715222
# Reactions     0.474711   0.439067
# Acceleration  0.444650   0.440249
# Vision        1.000000   0.694034
# Long_Pass     0.694034   1.000000

# %%
df_subset.var()
# Out:
# Age              22.043678
# Rating           50.813510
# Dribbling       356.712109
# Reactions        83.502335
# Acceleration    210.579596
# Vision          217.045707
# Long_Pass       242.338221
# dtype: float64
